# %% [markdown]
# # Requirements
#
# Run this notebook once before running any other notebooks in this project.

# %%
! pip3 install --upgrade xarray zarr gcsfs cftime nc-time-axis
# Out:
# WARNING: Ignoring invalid distribution ~umpy (/Users/scotthuang1228/Downloads/DSC 106/dsc106-project-3/dsc106-project3/lib/python3.11/site-packages)
# Requirement already satisfied: xarray in ./dsc106-project3/lib/python3.11/site-packages (2026.4.0)
# Requirement already satisfied: zarr in ./dsc106-project3/lib/python3.11/site-packages (3.1.6)
# Requirement already satisfied: gcsfs in ./dsc106-project3/lib/python3.11/site-packages (2026.5.0)
# Requirement already satisfied: cftime in ./dsc106-project3/lib/python3.11/site-packages (1.6.5)
# Requirement already satisfied: nc-time-axis in ./dsc106-project3/lib/python3.11/site-packages (1.4.1)
# Collecting numpy>=1.26 (from xarray)
#   Obtaining dependency information for numpy>=1.26 from https://files.pythonhosted.org/packages/8a/dc/df98c095978fa6ee7b9a9387d1d58cbb3d232d0e69ad169a4ce784bde4fd/numpy-2.4.4-cp311-cp311-macosx_14_0_arm64.whl.metadata
#   Using cached numpy-2.4.4-cp311-cp311-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: packaging>=24.2 in ./dsc106-project3/lib/python3.11/site-packages (from xarray) (26.2)
# Requirement already satisfied: pandas>=2.2 in ./dsc106-project3/lib/python3.11/site-packages (from xarray) (3.0.2)
# Requirement already satisfied: donfig>=0.8 in ./dsc106-project3/lib/python3.11/site-packages (from zarr) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in ./dsc106-project3/lib/python3.11/site-packages (from zarr) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in ./dsc106-project3/lib/python3.11/site-packages (from zarr) (0.16.5)
# Requirement already satisfied: typing-extensions>=4.12 in ./dsc106-project3/lib/python3.11/site-packages (from zarr) (4.15.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0 in ./dsc106-project3/lib/python3.11/site-packages (from gcsfs) (3.13.5)
# Requirement already satisfied: decorator>4.1.2 in ./dsc106-project3/lib/python3.11/site-packages (from gcsfs) (5.2.1)
# Requirement already satisfied: fsspec!=2026.4.0,>=2026.3.0 in ./dsc106-project3/lib/python3.11/site-packages (from gcsfs) (2026.3.0)
# Requirement already satisfied: google-auth-oauthlib in ./dsc106-project3/lib/python3.11/site-packages (from gcsfs) (1.3.1)
# Requirement already satisfied: google-auth>=1.2 in ./dsc106-project3/lib/python3.11/site-packages (from gcsfs) (2.50.0)
# Requirement already satisfied: google-cloud-storage-control in ./dsc106-project3/lib/python3.11/site-packages (from gcsfs) (1.11.0)
# Requirement already satisfied: google-cloud-storage>=3.9.0 in ./dsc106-project3/lib/python3.11/site-packages (from gcsfs) (3.10.1)
# Requirement already satisfied: requests in ./dsc106-project3/lib/python3.11/site-packages (from gcsfs) (2.33.1)
# Requirement already satisfied: matplotlib in ./dsc106-project3/lib/python3.11/site-packages (from nc-time-axis) (3.10.9)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./dsc106-project3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->gcsfs) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./dsc106-project3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->gcsfs) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./dsc106-project3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->gcsfs) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./dsc106-project3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->gcsfs) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./dsc106-project3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->gcsfs) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in ./dsc106-project3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->gcsfs) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./dsc106-project3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->gcsfs) (1.23.0)
# Requirement already satisfied: pyyaml in ./dsc106-project3/lib/python3.11/site-packages (from donfig>=0.8->zarr) (6.0.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./dsc106-project3/lib/python3.11/site-packages (from google-auth>=1.2->gcsfs) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in ./dsc106-project3/lib/python3.11/site-packages (from google-auth>=1.2->gcsfs) (48.0.0)
# Requirement already satisfied: google-api-core<3.0.0,>=2.27.0 in ./dsc106-project3/lib/python3.11/site-packages (from google-cloud-storage>=3.9.0->gcsfs) (2.30.3)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in ./dsc106-project3/lib/python3.11/site-packages (from google-cloud-storage>=3.9.0->gcsfs) (2.5.1)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in ./dsc106-project3/lib/python3.11/site-packages (from google-cloud-storage>=3.9.0->gcsfs) (2.8.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./dsc106-project3/lib/python3.11/site-packages (from pandas>=2.2->xarray) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./dsc106-project3/lib/python3.11/site-packages (from requests->gcsfs) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in ./dsc106-project3/lib/python3.11/site-packages (from requests->gcsfs) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in ./dsc106-project3/lib/python3.11/site-packages (from requests->gcsfs) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in ./dsc106-project3/lib/python3.11/site-packages (from requests->gcsfs) (2026.4.22)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./dsc106-project3/lib/python3.11/site-packages (from google-auth-oauthlib->gcsfs) (2.0.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in ./dsc106-project3/lib/python3.11/site-packages (from google-cloud-storage-control->gcsfs) (1.80.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in ./dsc106-project3/lib/python3.11/site-packages (from google-cloud-storage-control->gcsfs) (1.27.2)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in ./dsc106-project3/lib/python3.11/site-packages (from google-cloud-storage-control->gcsfs) (6.33.6)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in ./dsc106-project3/lib/python3.11/site-packages (from google-cloud-storage-control->gcsfs) (0.14.4)
# Requirement already satisfied: contourpy>=1.0.1 in ./dsc106-project3/lib/python3.11/site-packages (from matplotlib->nc-time-axis) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./dsc106-project3/lib/python3.11/site-packages (from matplotlib->nc-time-axis) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./dsc106-project3/lib/python3.11/site-packages (from matplotlib->nc-time-axis) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./dsc106-project3/lib/python3.11/site-packages (from matplotlib->nc-time-axis) (1.5.0)
# Requirement already satisfied: pillow>=8 in ./dsc106-project3/lib/python3.11/site-packages (from matplotlib->nc-time-axis) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in ./dsc106-project3/lib/python3.11/site-packages (from matplotlib->nc-time-axis) (3.3.2)
# Requirement already satisfied: cffi>=2.0.0 in ./dsc106-project3/lib/python3.11/site-packages (from cryptography>=38.0.3->google-auth>=1.2->gcsfs) (2.0.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in ./dsc106-project3/lib/python3.11/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage>=3.9.0->gcsfs) (1.74.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in ./dsc106-project3/lib/python3.11/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage>=3.9.0->gcsfs) (1.80.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in ./dsc106-project3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs) (0.6.3)
# Requirement already satisfied: six>=1.5 in ./dsc106-project3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.2->xarray) (1.17.0)
# Requirement already satisfied: oauthlib>=3.0.0 in ./dsc106-project3/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs) (3.3.1)
# Requirement already satisfied: pycparser in ./dsc106-project3/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth>=1.2->gcsfs) (3.0)
# Using cached numpy-2.4.4-cp311-cp311-macosx_14_0_arm64.whl (5.5 MB)
# WARNING: Ignoring invalid distribution ~umpy (/Users/scotthuang1228/Downloads/DSC 106/dsc106-project-3/dsc106-project3/lib/python3.11/site-packages)
# Installing collected packages: numpy
# WARNING: Ignoring invalid distribution ~umpy (/Users/scotthuang1228/Downloads/DSC 106/dsc106-project-3/dsc106-project3/lib/python3.11/site-packages)
# Successfully installed numpy
#
# [notice] A new release of pip is available: 23.2.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
! pip3 install --upgrade numexpr bottleneck
# Out:
# WARNING: Ignoring invalid distribution ~umpy (/Users/scotthuang1228/Downloads/DSC 106/dsc106-project-3/dsc106-project3/lib/python3.11/site-packages)
# Requirement already satisfied: numexpr in ./dsc106-project3/lib/python3.11/site-packages (2.14.1)
# Requirement already satisfied: bottleneck in ./dsc106-project3/lib/python3.11/site-packages (1.6.0)
# Collecting numpy>=1.23.0 (from numexpr)
#   Obtaining dependency information for numpy>=1.23.0 from https://files.pythonhosted.org/packages/8a/dc/df98c095978fa6ee7b9a9387d1d58cbb3d232d0e69ad169a4ce784bde4fd/numpy-2.4.4-cp311-cp311-macosx_14_0_arm64.whl.metadata
#   Using cached numpy-2.4.4-cp311-cp311-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Using cached numpy-2.4.4-cp311-cp311-macosx_14_0_arm64.whl (5.5 MB)
# WARNING: Ignoring invalid distribution ~umpy (/Users/scotthuang1228/Downloads/DSC 106/dsc106-project-3/dsc106-project3/lib/python3.11/site-packages)
# Installing collected packages: numpy
# WARNING: Ignoring invalid distribution ~umpy (/Users/scotthuang1228/Downloads/DSC 106/dsc106-project-3/dsc106-project3/lib/python3.11/site-packages)
# Successfully installed numpy
#
# [notice] A new release of pip is available: 23.2.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
